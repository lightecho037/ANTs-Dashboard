# %%
# while trying to initialize the project, I got the following error from react-app-rewired:
# npm audit fix --force

# In order to fix it, I used the following steps:
# 1 - run the command "npm audit" 
# to detect if there are any vulnerabilities

# 2 - run the command "npm audit fix"
# to display the list of vulnerabilities

# 3 - delete the package-lock.json file and node_modules folder

# 4 - update the package.json file with the correct versions

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 5 - after adding the overrides to the package.json file, run the command "npm install"
# the package-lock.json and node_modules will be created again and the project will be ready

# %% [markdown]
# ![image.png](attachment:image.png)
